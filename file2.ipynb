# %% [markdown]
# <a href="https://colab.research.google.com/github/esusrutha/zeroshot/blob/main/file2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Read in the CSV files
RESULTS_DIR = 'drive/MyDrive'
df1 = pd.read_csv(RESULTS_DIR + '/D11.csv', encoding='latin1', engine='python')
df2 = pd.read_csv(RESULTS_DIR + '/D2.csv', encoding='latin1', engine='python')


# Merge the dataframes
merged_df = pd.concat([df1, df2], axis=0)

# Create a new column called 'category' and initialize it with 'None'
merged_df['category'] = None

# Create a list of adive,china,mask,news,transporation,usa and vaccine
Advice = ["['Stay at home']","['wash hands']","['wear mask']","['social distancing']"]
China = ["['Wuhan']","['China Coronavirus Updates']","['China news']","['other tweets related to China']"]
Mask = ["['Mask shortage']","['wear mask']","['mask types']","['N50']","['N95']","['3M8210']","['3M9001']","['3M9322']","['3M9501']"]
News = ["['Coronavirus updates']","['news']","['rules']"]
Transportation = ["['Flights']","['traffic']","['traveling']"]
USA = ["['U.S. Coronavirus Updates']","['COVID19']","['U.S. news']","['United States']","['US']","['USA']"]
Vaccine = ["['Vaccine news']","['vaccine progress']","['vaccine injection']"]

# Iterate over the rows of the dataframe
for index, row in merged_df.iterrows():
    # Check if the hashtags column contains  'Stay at home','wash hands','wear mask' or 'social distancing'
    if row['hashtags'] in Advice:
        # If it does, set the category to 'Advice'
        merged_df.at[index, 'category'] = 'Advice'
    elif row['hashtags'] in China:
        # If it does, set the category to 'China'
        merged_df.at[index, 'category'] = 'China'
    elif row['hashtags'] in Mask:
        # If it does, set the category to 'Mask'
        merged_df.at[index, 'category'] = 'Mask'
    elif row['hashtags'] in News:
        # If it does, set the category to 'News'
        merged_df.at[index, 'category'] = 'News'
    elif row['hashtags'] in Transportation:
        # If it does, set the category to 'Transportation'
        merged_df.at[index, 'category'] = 'Transportation'
    elif row['hashtags'] in USA:
        # If it does, set the category to 'USA'
        merged_df.at[index, 'category'] = 'USA'
    elif row['hashtags'] in Vaccine:
        # If it does, set the category to 'Vaccine'
        merged_df.at[index, 'category'] = 'Vaccine'
    
# Print the updated dataframe
print(merged_df["category"].value_counts())
# Out:
# Mask              469
# Advice            311
# USA               224
# News              216
# Vaccine           134
# Transportation    132
# China             131
# Name: category, dtype: int64

# %%
pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 57.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.4 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 63.9 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=cca5b7abbafe4f5d181f0064990ce7f73f16264f819dd96b796b25bf60c25f66
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, sentence-transformers
# Successfully installed huggingface-hub-0.13.4 sentence-transformers-2.2.2 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.28.1

# %%
pip install ConceptNet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ConceptNet
#   Downloading ConceptNet-5.7.0.tar.gz (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting snakemake
#   Downloading snakemake-7.25.0-py3-none-any.whl (366 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 kB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from ConceptNet) (8.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from ConceptNet) (2.27.1)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.3 MB/s eta 0:00:00
# Collecting msgpack-python
#   Downloading msgpack-python-0.5.6.tar.gz (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.0/139.0 kB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from ConceptNet) (1.22.4)
# Requirement already satisfied: langcodes>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from ConceptNet) (3.3.0)
# Collecting wordfreq>=2.0.1
#   Downloading wordfreq-3.0.3-py3-none-any.whl (56.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 MB 12.7 MB/s eta 0:00:00
# Collecting xmltodict<0.12.0,>=0.11.0
#   Downloading xmltodict-0.11.0-py2.py3-none-any.whl (7.2 kB)
# Collecting ordered_set
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 82.1 MB/s eta 0:00:00
# Collecting marisa-trie
#   Downloading marisa_trie-0.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.9 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2021.7.6 in /usr/local/lib/python3.9/dist-packages (from wordfreq>=2.0.1->ConceptNet) (2022.10.31)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.9/dist-packages (from wordfreq>=2.0.1->ConceptNet) (1.0.5)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->ConceptNet) (0.2.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from marisa-trie->ConceptNet) (67.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->ConceptNet) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->ConceptNet) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->ConceptNet) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->ConceptNet) (1.26.15)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (1.4.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (5.9.4)
# Collecting yte<2.0,>=1.0
#   Downloading yte-1.5.1-py3-none-any.whl (7.5 kB)
# Collecting connection-pool>=0.0.3
#   Downloading connection_pool-0.0.3.tar.gz (3.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting stopit
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting configargparse
#   Downloading ConfigArgParse-1.5.3-py3-none-any.whl (20 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (0.8.10)
# Collecting reretry
#   Downloading reretry-0.11.8-py2.py3-none-any.whl (5.6 kB)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (5.8.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (4.3.3)
# Collecting pulp>=2.0
#   Downloading PuLP-2.7.0-py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 56.6 MB/s eta 0:00:00
# Collecting throttler
#   Downloading throttler-1.2.2-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: smart-open>=3.0 in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (6.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (6.0)
# Collecting gitpython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: jinja2<4.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (3.1.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (1.14.1)
# Requirement already satisfied: docutils in /usr/local/lib/python3.9/dist-packages (from snakemake->ConceptNet) (0.16)
# Collecting humanfriendly
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.6 MB/s eta 0:00:00
# Collecting toposort>=1.10
#   Downloading toposort-1.10-py3-none-any.whl (8.5 kB)
# Collecting datrie
#   Downloading datrie-0.8.2.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 7.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2<4.0,>=3.0->snakemake->ConceptNet) (2.1.2)
# Collecting dpath<3.0,>=2.0
#   Downloading dpath-2.1.5-py3-none-any.whl (17 kB)
# Collecting plac<2.0.0,>=1.3.4
#   Downloading plac-1.3.5-py2.py3-none-any.whl (22 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->snakemake->ConceptNet) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->snakemake->ConceptNet) (22.2.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/dist-packages (from nbformat->snakemake->ConceptNet) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.9/dist-packages (from nbformat->snakemake->ConceptNet) (5.7.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->snakemake->ConceptNet) (2.16.3)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core->nbformat->snakemake->ConceptNet) (3.2.0)
# Building wheels for collected packages: ConceptNet, msgpack-python, connection-pool, datrie, stopit
#   Building wheel for ConceptNet (setup.py) ... done
#   Created wheel for ConceptNet: filename=ConceptNet-5.7.0-py3-none-any.whl size=5309055 sha256=35d2ef80a9bc8cc33bf3b27fd8aca7c6e70f6074347a86198c3c20b7fb0e2daa
#   Stored in directory: /root/.cache/pip/wheels/a9/28/00/cb66087a5a51f4f7bf33ea374a3f596ffd8d82ef4c11e13413
#   Building wheel for msgpack-python (setup.py) ... done
#   Created wheel for msgpack-python: filename=msgpack_python-0.5.6-cp39-cp39-linux_x86_64.whl size=216964 sha256=525d4fc3570cc93ea6059673d42f3d6980757bf64e2fcd7c14ef1cc0a8e2b1cf
#   Stored in directory: /root/.cache/pip/wheels/8f/ce/bc/08b302b5ab90315dc9fc538c2d29b5d04087ce5be3e804d834
#   Building wheel for connection-pool (setup.py) ... done
#   Created wheel for connection-pool: filename=connection_pool-0.0.3-py3-none-any.whl size=4081 sha256=702bc0fe3562103777c831109917331138ec257dfb2d1851766b3447cfd8abb3
#   Stored in directory: /root/.cache/pip/wheels/d7/99/1f/ed919974bc5a1ce7357f3a90d519e6cbab066fac4d4d55b1b9
#   Building wheel for datrie (pyproject.toml) ... done
#   Created wheel for datrie: filename=datrie-0.8.2-cp39-cp39-linux_x86_64.whl size=732687 sha256=11e5b0570b900eda1baf07be78e91262a38fe3386ebe19174cfcae520cd15418
#   Stored in directory: /root/.cache/pip/wheels/e9/04/17/1d0bd7b371c1514a6216fd2de4f33742a071c9392c8f48bcc1
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11954 sha256=04da224a9eae35643c0d0d8bc3ca4dfc3820576730f97583799968342b527266
#   Stored in directory: /root/.cache/pip/wheels/48/8c/93/3afb1916772591fe6bcc25cdf8b1c5bdc362f0ec8e2f0fd413
# Successfully built ConceptNet msgpack-python connection-pool datrie stopit
# Installing collected packages: xmltodict, toposort, throttler, stopit, pulp, plac, msgpack-python, connection-pool, smmap, reretry, psycopg2-binary, ordered_set, marisa-trie, humanfriendly, ftfy, dpath, datrie, configargparse, yte, wordfreq, gitdb, gitpython, snakemake, ConceptNet
# Successfully installed ConceptNet-5.7.0 configargparse-1.5.3 connection-pool-0.0.3 datrie-0.8.2 dpath-2.1.5 ftfy-6.1.1 gitdb-4.0.10 gitpython-3.1.31 humanfriendly-10.0 marisa-trie-0.8.0 msgpack-python-0.5.6 ordered_set-4.1.0 plac-1.3.5 psycopg2-binary-2.9.6 pulp-2.7.0 reretry-0.11.8 smmap-5.0.0 snakemake-7.25.0 stopit-1.1.2 throttler-1.2.2 toposort-1.10 wordfreq-3.0.3 xmltodict-0.11.0 yte-1.5.1

# %%
import pandas as pd
import torch
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Read the merged DataFrame containing the tweets and categories
merged_df = pd.concat([df1, df2], axis=0)

# Load the pre-trained S-BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Convert the tweets into sentence embeddings
tweet_embeddings = model.encode(merged_df['text'].values)

# Define the possible label names
label_names = ['Vaccine','USA','Transportation','News','Mask','China','Advice']

# Convert the label names into label embeddings
label_embeddings = model.encode(label_names)

# Calculate the cosine similarities between each tweet embedding and each label embedding
cos_similarities = cosine_similarity(tweet_embeddings, label_embeddings)

# Assign the label with the highest cosine similarity to each tweet
predicted_labels = [label_names[i] for i in cos_similarities.argmax(axis=1)]

# Add the predicted labels to the merged DataFrame
merged_df['predicted_label'] = predicted_labels

# Print the resulting DataFrame
print(predicted_labels)
# Out:
# Downloading (…)821d1/.gitattributes:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)8d01e821d1/README.md:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading (…)d1/added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)01e821d1/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)821d1/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading (…)8d01e821d1/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)1e821d1/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# ['China', 'USA', 'Advice', 'Vaccine', 'News', 'News', 'Vaccine', 'Advice', 'Vaccine', 'USA', 'Mask', 'USA', 'Vaccine', 'USA', 'Vaccine', 'Vaccine', 'Advice', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'Advice', 'USA', 'China', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'Advice', 'Vaccine', 'News', 'Vaccine', 'Advice', 'Vaccine', 'News', 'China', 'Mask', 'China', 'USA', 'USA', 'Vaccine', 'Vaccine', 'Vaccine', 'USA', 'Vaccine', 'Vaccine', 'Vaccine', 'China', 'Vaccine', 'Vaccine', 'China', 'USA', 'Vaccine', 'Vaccine', 'News', 'Vaccine', 'Vaccine', 'Vaccine', 'China', 'Vaccine', 'Vaccine', 'China', 'USA', 'Advice', 'Vaccine', 'Mask', 'Vaccine', 'News', 'News', 'China', 'Advice', 'China', 'News', 'Vaccine', 'News', 'Vaccine', 'Advice', 'China', 'USA', 'News', 'News', 'Vaccine', 'Vaccine', 'Advice', 'China', 'Vaccine', 'Vaccine', 'China', 'Vaccine', 'USA', 'USA', 'Vaccine', 'Vaccine', 'USA', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'Advice', 'Vaccine', 'China', 'Vaccine', 'Vaccine', 'China', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'China', 'USA', 'Mask', 'Vaccine', 'Vaccine', 'News', 'China', 'Vaccine', 'China', 'Vaccine', 'News', 'Vaccine', 'Advice', 'Advice', 'Vaccine', 'Vaccine', 'Vaccine', 'Vaccine', 'News', 'Vaccine', 'China', 'China', 'Advice', 'Vaccine', 'Vaccine', 'USA', 'Mask', 'China', 'Vaccine', 'China', 'News', 'Vaccine', 'Mask', 'USA', 'USA', 'China', 'Vaccine', 'Advice', 'Advice', 'China', 'Vaccine', 'Vaccine', 'Vaccine', 'USA', 'Vaccine', 

# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: retrofit in /usr/local/lib/python3.9/dist-packages (0.1.7)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.9/dist-packages (from retrofit) (3.3.5)
# Requirement already satisfied: datatable in /usr/local/lib/python3.9/dist-packages (from retrofit) (1.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from retrofit) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from retrofit) (1.5.3)
# Requirement already satisfied: polars in /usr/local/lib/python3.9/dist-packages (from retrofit) (0.17.2)
# Requirement already satisfied: catboost in /usr/local/lib/python3.9/dist-packages (from retrofit) (1.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from retrofit) (1.10.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.9/dist-packages (from retrofit) (1.7.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost->retrofit) (0.20.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost->retrofit) (1.16.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost->retrofit) (5.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost->retrofit) (3.7.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->retrofit) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->retrofit) (2.8.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/dist-packages (from lightgbm->retrofit) (0.40.0)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.9/dist-packages (from lightgbm->retrofit) (1.2.2)
# Requirement already satisfied: typing_extensions>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from polars->retrofit) (4.5.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn!=0.22.0->lightgbm->retrofit) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn!=0.22.0->lightgbm->retrofit) (3.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost->retrofit) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost->retrofit) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost->retrofit) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost->retrofit) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost->retrofit) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost->retrofit) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost->retrofit) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost->retrofit) (1.0.7)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost->retrofit) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->catboost->retrofit) (3.15.0)

# %%
import pandas as pd
import torch
from sentence_transformers import SentenceTransformer, util
from retrofit import Retrofitter


# Define the sets of tweets and labels
Advice = ["['Stay at home']","['wash hands']","['wear mask']","['social distancing']"]
China = ["['Wuhan']","['China Coronavirus Updates']","['China news']","['other tweets related to China']"]
Mask = ["['Mask shortage']","['wear mask']","['mask types']","['N50']","['N95']","['3M8210']","['3M9001']","['3M9322']","['3M9501']"]
News = ["['Coronavirus updates']","['news']","['rules']"]
Transportation = ["['Flights']","['traffic']","['traveling']"]
USA = ["['U.S. Coronavirus Updates']","['COVID19']","['U.S. news']","['United States']","['US']","['USA']"]
Vaccine = ["['Vaccine news']","['vaccine progress']","['vaccine injection']"]
tweets = Advice + China + Mask + News + Transportation + USA + Vaccine
labels = ["Vaccine","USA","Transportation","News","Mask","China","Advice"]

# Read CSV files and merge them into a single dataframe
RESULTS_DIR = 'drive/MyDrive'
df1 = pd.read_csv(RESULTS_DIR + '/D11.csv', encoding='latin1', engine='python')
df2 = pd.read_csv(RESULTS_DIR + '/D2.csv', encoding='latin1', engine='python')
df = pd.concat([df1, df2], ignore_index=True)

# Extract string attributes from hashtag values
df['hashtags'] = df['hashtags'].str.findall(r"'(.*?)'").apply(lambda x: [item for item in x if item])

# Filter tweets by hashtags
df['tweet_type'] = df['hashtags'].apply(lambda x: list(set(x).intersection(set(tweets))))

# Load the pre-trained S-BERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Embed the tweets and labels using the S-BERT model
tweet_embeddings = model.encode(df['text'])
label_embeddings = model.encode(labels)

# Load the knowledge graph (ConceptNet)
knowledge_graph = pd.read_csv('conceptnet.csv')

# Retrofit the knowledge graph embeddings
retrofitter = Retrofitter(model=model, graph=knowledge_graph, dim=768)
retrofitter.fit()

# Project the tweet embeddings and label embeddings onto the knowledge graph embedding space
projected_tweet_embeddings = torch.matmul(tweet_embeddings, retrofitter.P)
projected_label_embeddings = torch.matmul(label_embeddings, retrofitter.P)

# Classify the tweets using cosine similarity
for i, tweet_embedding in enumerate(projected_tweet_embeddings):
    max_sim = 0
    for j, label_embedding in enumerate(projected_label_embeddings):
        sim = util.cos_sim(tweet_embedding, label_embedding)
        if sim > max_sim:
            max_sim = sim
            tweet_label = labels[j]
    df.loc[i, 'tweet_label'] = tweet_label

# Print the classified tweets
print(df[['text', 'tweet_label']])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-5c9bc322407d> in <cell line: 4>()
#       2 import torch
#       3 from sentence_transformers import SentenceTransformer, util
# ----> 4 from retrofit import Retrofitter
#       5
#       6
#
# ImportError: cannot import name 'Retrofitter' from 'retrofit' (/usr/local/lib/python3.9/dist-packages/retrofit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import pandas as pd

# Read in the CSV files
RESULTS_DIR = 'drive/MyDrive'
df1 = pd.read_csv(RESULTS_DIR + '/D11.csv', encoding='latin1', engine='python')
df2 = pd.read_csv(RESULTS_DIR + '/D2.csv', encoding='latin1', engine='python')


# Merge the dataframes
merged_df = pd.concat([df1, df2], axis=0)

# %%
import spacy
import numpy as np
import pandas as pd
import os

# Define the paths to the CSV files
file1_path = '/content/drive/MyDrive/D11.csv'
file2_path = '/content/drive/MyDrive/D2.csv'

# Loop through the first file
for dirname, _, filenames in os.walk(file1_path):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Loop through the second file
for dirname, _, filenames in os.walk(file2_path):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
nlp = spacy.load('en_core_web_sm')

doc = nlp("The 22-year-old recently won ATP Challenger tournament.")

for tok in doc:
    print(tok.text, "...", tok.dep_)
# Out:
# The ... det
# 22 ... nummod
# - ... punct
# year ... npadvmod
# - ... punct
# old ... nsubj
# recently ... advmod
# won ... ROOT
# ATP ... compound
# Challenger ... compound
# tournament ... dobj
# . ... punct

# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4) (2.4)

# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
import pandas as pd

# Read in the first CSV file
file1_path = pd.read_csv("/content/drive/MyDrive/D11.csv",encoding='latin1', engine='python')

# Read in the second CSV file
file2_path = pd.read_csv("/content/drive/MyDrive/D2.csv",encoding='latin1', engine='python')

# Check the shape of each DataFrame
print("Shape of file1:", file1_path.shape)
print("Shape of file2:", file2_path.shape)
# Merge the two DataFrames together
merged = pd.concat([file1_path, file2_path], axis=0)

# Check the shape of the merged DataFrame
print("Shape of merged DataFrame:", merged.shape)
merged.shape
# Out:
# Shape of file1: (1769, 13)
# Shape of file2: (2009, 13)
# Shape of merged DataFrame: (3778, 13)
# (3778, 13)

# %%
pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.9/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (1.22.4)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (0.13.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (0.1.97)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (2.0.0+cu118)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (4.27.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.10.7)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence_transformers) (3.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence_transformers) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)

# %%
merged
# Out:
#                 user_name                  user_location  \
# 0     Tom Basile ðºð¸                   New York, NY
# 1         Time4fisticuffs               Pewee Valley, KY
# 2             ethel mertz           Stuck in the Middle
# 3                DIPR-J&K              Jammu and Kashmir
# 4     ð¹ Franz Schubert         ÐÐ¾Ð²Ð¾ÑÐ¾ÌÑÑÐ¸Ñ
# ...                   ...                            ...
# 2004     Bruno A. Bonechi                            NaN
# 2005           UAE Forsan  United Arab Emirates ð¦ðª
# 2006          TheArgus.in             Bhubaneswar, India
# 2007      MSF East Africa                 Nairobi, Kenya
# 2008           Lisa White                            NaN
#
#                                                                                                                                                user_description  \
# 0     Husband, Father, Columnist & Commentator. Author of Tough Sell: Fighting the Media War in Iraq. Bush Admin Alum. Newsmax Contributor. Fmr Exec Dir NYSGOP
# 1                                 #Christian #Catholic #Conservative #Reagan #Republican #Capitalist; Sports lover - #BBN #Cincinnati #Reds #Bengals #Trump2020
# 2                                                                                                         #Browns #Indians #ClevelandProud #[]_[] #Cavs #Resist
# 2007  For many #refugees, humanitarian services are a crucial lifeline &amp; the only means to access food &amp; health. \n\nIn Dagâ¦ https://t.co/Qu1V7XvzaR
# 2008       Dm to buy nudes videos calls and custom videosâ¤ï¸Snapme : Lisa2bae â¥â¨ #horny #sexy #sex #porn #nude #sellingnudesâ¦ https://t.co/ICoo0KJNLY
#
#                    source  is_retweet                        hashtags
# 0     Twitter for Android       False              ['Vaccine news']
# 1     Twitter for Android       False           ['vaccine injection']
# 2      Twitter for iPhone       False                         ['USA']
# 3     Twitter for Android       False               ['United States']
# 4         Twitter Web App       False                         ['N50']
# ...                   ...         ...                             ...
# 2004       Hootsuite Inc.       False                     ['Wuhan']
# 2005       Hootsuite Inc.       False           ['vaccine injection']
# 2006      Twitter Web App       False                         ['N50']
# 2007               Buffer       False  ['Mask shortage']
# 2008            TweetDeck       False              ['Vaccine news']
#
# [3778 rows x 13 columns]

# %%
doc = nlp("confused and frustrated, connie decides to leave on her own.")

for tok in doc:
    print(tok.text, "...", tok.dep_)
# Out:
# confused ... advcl
# and ... cc
# frustrated ... conj
# , ... punct
# connie ... nsubj
# decides ... ROOT
# to ... aux
# leave ... xcomp
# on ... prep
# her ... poss
# own ... pobj
# . ... punct

# %%
def get_entities(sent):
    ## chunk 1
    ent1 = ""
    ent2 = ""

    prv_tok_dep = ""  # dependency tag of previous token in the sentence
    prv_tok_text = ""  # previous token in the sentence

    prefix = ""
    modifier = ""

    #############################################################

    for tok in nlp(sent):
        ## chunk 2
        # if token is a punctuation mark then move on to the next token
        if tok.dep_ != "punct":
            # check: token is a compound word or not
            if tok.dep_ == "compound":
                prefix = tok.text
                # if the previous word was also a 'compound' then add the current word to it
                if prv_tok_dep == "compound":
                    prefix = prv_tok_text + " " + tok.text

            # check: token is a modifier or not
            if tok.dep_.endswith("mod") == True:
                modifier = tok.text
                # if the previous word was also a 'compound' then add the current word to it
                if prv_tok_dep == "compound":
                    modifier = prv_tok_text + " " + tok.text

            ## chunk 3
            if tok.dep_.find("subj") == True:
                ent1 = modifier + " " + prefix + " " + tok.text
                prefix = ""
                modifier = ""
                prv_tok_dep = ""
                prv_tok_text = ""

                ## chunk 4
            if tok.dep_.find("obj") == True:
                ent2 = modifier + " " + prefix + " " + tok.text

            ## chunk 5  
            # update variables
            prv_tok_dep = tok.dep_
            prv_tok_text = tok.text
    #############################################################

    return [ent1.strip(), ent2.strip()]

# %%
get_entities("the film had 200 patents")
# Out:
# ['film', '200  patents']

# %%
entity_pairs = []

for i in tqdm(merged["text"]):
    entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 3778/3778 [00:51<00:00, 73.80it/s]

# %%
entity_pairs[10:20]
# Out:
# [['graphicdesigner', 'https://t.co/4NUrGX6EmA  #'],
#  ["fast  's", '¦'],
#  ['Rajasthan Government', 'today Man Singh COVID-19'],
#  ['', 'Tower Junction Dimapur'],
#  ['52273 Actice #', '61729 Actice cases'],
#  ['', 'back  more'],
#  ['darkest  we', '# https://t.co/YLlS4Kj85câ\x80 ¦'],
#  ['natural  experts', 'natural  curve'],
#  ['@EvanAKilgore Election Polls', 'withoutâ\x80 ¦'],
#  ['', 'South Africa']]

# %%
def get_relation(sent):

    doc = nlp(sent)

    # Matcher class object 
    matcher = Matcher(nlp.vocab)

    #define the pattern 
    pattern = [{'DEP':'ROOT'},
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

    matcher.add("matching_1", [pattern], on_match=None) 

    matches = matcher(doc)
    k = len(matches) - 1

    span = doc[matches[k][1]:matches[k][2]] 

    return(span.text)

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %%
relations = [get_relation(i) for i in tqdm(merged['text'])]
# Out:
# 100%|██████████| 3778/3778 [00:50<00:00, 74.65it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# is              116
# COVID19          59
# ¦                55
# coronavirus      48
# are              46
# have             37
# Help             32
# preprint         30
# be               27
# Vishal           26
# 's               25
# was              21
# started          20
# need             20
# covid19          19
# Check            18
# had              16
# cases            16
# says             15
# pledged          14
# has              12
# know             12
# announced        12
# want             12
# think            12
# tested           11
# Watch            11
# made             10
# get              10
# Keep             10
# Remember         10
# reports          10
# COVID            10
# been             10
# Let               9
# Is                9
# go                9
# aâ               8
# doing             8
# TRACKER           8
# said              8
# delegation        8
# took              8
# Updated           8
# alreadyvideo      8
# protect           8
# see               8
# joins             8
# say               8
# Source            8
# dtype: int64

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})
kg_df
# Out:
#                       source                                    target  \
# 0              more  players                                     Aâ ¦
# 1                     effort                                   COVID19
# 2               simple  that                                 always  ¦
# 3        July Media Bulletin  @kansalrohit69 ¦ https://t.co/MN0EEcsJHh
# 4                     as  it
# ...                      ...                                       ...
# 3773    global  stakeholders                      direct  consequences
# 3774         community group      distressed ¦ https://t.co/YJYQe3jxkc
# 3775          four  patients                  # ventilator Bhubaneswar
# 3776  humanitarian  services        only Dagâ https://t.co/Qu1V7XvzaR
# 3777         custom Lisa2bae                        # sellingnudesâ ¦
#
#              edge
# 0       made more
# 1           claim
# 2              is
# 3          @ANIâ
# 4     Politicians
# ...           ...
# 3773           is
# 3774   distribute
# 3775  admitted to
# 3776           In
# 3777        horny
#
# [3778 rows x 3 columns]

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (3.7.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
pip install networkx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (3.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'DejaVu Sans'

# %%
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='red', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="composed by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(5,5))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='green', node_size=150, edge_cmap=plt.cm.Blues, pos = pos, font_weight='bold')
plt.show(G)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3dc978f75b7c> in <cell line: 1>()
# ----> 1 G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="composed by"], "source", "target",
#       2                           edge_attr=True, create_using=nx.MultiDiGraph())
#       3
#       4 plt.figure(figsize=(5,5))
#       5 pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
#
# NameError: name 'nx' is not defined
